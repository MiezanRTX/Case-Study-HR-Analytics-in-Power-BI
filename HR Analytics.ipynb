# %% [markdown]
# ## Employee Insights and Improvement Plan
#
# This chapter is about using your Power BI skills to extract insights using DAX and learn how to build custom visuals that you can use throughout your report. Atlas Labs would like some answers on its employee demographics and performance. Luckily, they have you on their team as a Data Analyst to help them explore their data further.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---
#
# ## Understanding attrition
#
# Great work so far; you've managed to build three report pages that provide insights to the HR department. The last key insight HR is looking for is understanding employee attrition.
#
# Reminder: Employee attrition, also known as employee churn or turnover, refers to employees leaving an organization for any reason (voluntary or involuntary).

# %% [markdown]
# ### Steps
# 1. For this exercise, create a new page in the report called "Attrition". Next, copy and paste OR create a new card visual using the % Attrition Rate measure.
#
# 2. Select an appropriate visualization that displays the % Attrition Rate for each department and job role.
#
# 3. First, create a new measure that uses CALCULATE() on our InactiveEmployees and makes use of the USERELATIONSHIP function. Name this measure InactiveEmployeesDate.
#         Next, create a measure that calculates the rate of attrition based on InactiveEmployeesDate and TotalEmployeesDate. Name this % Attrition Rate Date. Format as a percentage with one decimal place.
#
#
#         InactiveEmployeesDate = CALCULATE([InactiveEmployees], USERELATIONSHIP(DimEmployee[___], DimDate[___]))
#
#         % Attrition Rate Date = DIVIDE([___], [___])
#
#
# 4. For this exercise, create a new page in the report called "Attrition". Next, copy and paste OR create a new card visual using the % Attrition Rate measure.
#
# 5. Which department and job role has the highest attrition rate?
#     -   Sales - Sales Representative

# %% [markdown]
# ### Results
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Questions
# 1. How does the step 3. works?

# %% [markdown]
# ---
#
# # Other factors that impact attrition
#
# Now that we have some initial insight into which department and cohorts see the most turnover of employees - we can add additional context to see if we can figure out what other factors affect attrition.
#
# ### Steps
# 1. Select an appropriate visualization that displays the % Attrition Rate and TotalEmployees for Business Travel.
#
# 2. Select an appropriate visualization that displays the % Attrition Rate based on whether an employee does overtime or not.
#
# 3. Select an appropriate visualization that displays the % Attrition Rate based on years working for Atlas Labs.
#
# 4. What is the attrition rate for employees who are frequent travellers?
#     - 24.9%
#
#
#
# ### Results
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Insights on attrition
# From the charts we've just built, we can see some interesting insights on attrition that can help us prioritize which issues to solve first.
#
# We can see from our last exercise that our employees that have been considered frequent travelers have the highest attrition rate despite only making up 19% of the total hires.
#
# What action would you suggest HR take?
# - Review travel requirement policy and survey employees on feelings around travel frequency.

# %% [markdown]
# ---
# ## Layout design improvement
#
# Now that our visualizations have been created, we want to implement best practices to make a visually appealing report that users will engage with on a regular basis.
#
# We'll start by organizing the placement of visuals on the page.
#
# A color palette has been advised, but feel free to change the colors at your own discretion.
#
# ### Improvements
# 1. Change theme format.
# 2. Reorganize visualizations for every report page.
# 3. Add in navigation buttons for ease of access to every report.
#
# ### Screenshots
# #### Overview Page
# ![image.png](attachment:image.png)
#
# #### Demographcis Page
# ![image-2.png](attachment:image-2.png)
#
# #### Performance Tracker
# ![image-3.png](attachment:image-3.png)
#
# #### Attrition
# ![image-4.png](attachment:image-4.png)
